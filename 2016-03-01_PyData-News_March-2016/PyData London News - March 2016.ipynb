# %%
# import Image
from IPython.display import Image, HTML, IFrame, YouTubeVideo

# %% [markdown]
# # PyData London News <small> March 2016 </small>

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # Matplotlib 2.0 and the Viridis colour scheme

# %% [markdown]
# + Viridis is a yellow/blue spectrum that's free to use
# + "matplotlib 2.0 == matplotlib 1.5 + default style changes"
# + What's new in 1.5? http://matplotlib.org/devdocs/users/whats_new.html
#     - Interactive OO usage
#     - Working with labeled data like pandas DataFrames
#     - New colour maps

# %%
IFrame('http://matplotlib.org/style_changes.html', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="http://matplotlib.org/style_changes.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # LIGO ipython love

# %% [markdown]
# + Gravity acts as a wave? Who knew!?
# + Laser Interferometer Gravitational-Wave Observatory (Ligo)
# + Used Matplotlib for the publication plots

# %%
Image('images/ligo_figure1.png')

# %%
IFrame('https://losc.ligo.org/s/events/GW150914/GW150914_tutorial.html', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://losc.ligo.org/s/events/GW150914/GW150914_tutorial.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src='https://www.theguardian.com/science/2016/feb/11/gravitational-waves-discovery-hailed-as-breakthrough-of-the-century', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.theguardian.com/science/2016/feb/11/gravitational-waves-discovery-hailed-as-breakthrough-of-the-century"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # The Ian and Emlyn show went on the road!
#
# * Ian and I record for the Podcast talking about PyData London
# * The episode will go up in a couple of weeks

# %%
IFrame(src='http://pythonpodcast.com/', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="http://pythonpodcast.com/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyData London CfP closed — thank you to all those who submitted!
#
# * CFP is closed
# * We've had 67 talk submissions
#   - about 46 needed to fill the conference
#   - up from last year
# * We've had 9 tutorial submissions
#   - about 8 to fill the conference
#   - down slightly from last year

# %%
Image(filename='images/pydatalondon_cfp.png')

# %% [markdown]
# # When members join has yearly variations

# %%
Image('images/CDF of when members joined each month 2016-03-01.png', width=800, height=600)

# %% [markdown]
# # POTM - numexpr <small>Fast numerical expression evaluation</small>

# %%
IFrame('https://pypi.python.org/pypi/numexpr', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://pypi.python.org/pypi/numexpr"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
