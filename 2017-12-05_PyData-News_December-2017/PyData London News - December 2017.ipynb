# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo
default_size = {'width': 1024, 'height': 600}

# %% [markdown]
# # PyData London News <small>December 2017</small>
# ## Wifi: GST-Man, pw: xxx

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # Save the Date: Next Meetup 9th January 2018
#
# + We're breaking our own "first Tuesday of the month" rule
# + It won't happen again (like we told you last year)

# %% [markdown]
# # EuroPython 2018 (23-29 July in Edinburgh)
#
# + A whole Pythonic week!
# + ~1200 attendees
# + Monday-Tuesday: workshops and trainings
# + Wednesday-Friday: main event (talks, keynotes and expo)
# + Saturday-Sunday: sprints
# + Follow [@EuroPython](https://www.twitter.com/europython)

# %%
IFrame(src='http://www.europython-society.org/post/167520379525/europython-2018-location-and-dates', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="http://www.europython-society.org/post/167520379525/europython-2018-location-and-dates"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyCon Italy 2018 (CfP open)
#
# + 19-22 April in Florence
# + CfP open until 7th January
# + Great PyData track
# + https://www.pycon.it/en/
# + Follow [@PyConIT](https://www.twitter.com/pyconit)

# %%
Image('images/pycon_it.png', **default_size)

# %% [markdown]
# # POTM - Bounter <small>Probabilistic counting of item frequencies in large data sets</small>
#
# + Efficient Counter that uses a limited (bounded) amount of memory regardless of data size.
# + Like a Python dict, or a Counter, for huge data sets
# + Think dictionary building or collocation detection for billions of items
# + https://github.com/RaRe-Technologies/bounter

# %%
Image('images/bounter.png', **default_size)

# %% [markdown]
# # 2017 in Review

# %% [markdown]
# ## Increased ~30%, from ~4500 to ~6500 meetup members

# %%
Image('images/meetup_page.png', **default_size)

# %% [markdown]
# # 1 conference and 11 meetups (this is number 40!)
#
# + PyData Cardiff started!
# + PyCon UK PyData track started!

# %%
Image('images/pydata_london_2017.png', **default_size)

# %% [markdown]
# ## PyData London is people-powered, so thank **you**!

# %% [markdown]
# # PyData London 2018 is happening!

# %% [markdown]
# # PyData London 2018
#
# + 27-29 April 2018
# + New venue, ~500 attendees
# + Fri: Tutorials; Sat-Sun: main event
# + 3 parallel tracks, 1 unconference track (hackathon, sprints, etc.)
# + Beginner's Bootcamp on Wed-Thur
# + Mentorship Programme: we want new speakers!
# + Call for Sponsorship
