# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo

# %% [markdown]
# # PyData London News <small>November 2016</small>
# ## Wifi: GST-Man, pw: raspberry28

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # A Dramatic Tour through Python’s Data Visualization Landscape (including ggplot and Altair) <small> Dan Saber, October 2nd </small>

# %%
IFrame(src='https://dansaber.wordpress.com/2016/10/02/a-dramatic-tour-through-pythons-data-visualization-landscape-including-ggplot-and-altair/', height=600, width=1000)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="https://dansaber.wordpress.com/2016/10/02/a-dramatic-tour-through-pythons-data-visualization-landscape-including-ggplot-and-altair/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Python Data Science book
#
# + Early release of the book now available at O'Reilly
# + Jake Van De Plas, author of "Pythonic Perambulations" blog
# + Code examples all in notebooks and up at https://github.com/jakevdp/PythonDataScienceHandbook

# %%
Image('https://pbs.twimg.com/media/Cp6hC0gUsAEEmvi.jpg')

# %% [markdown]
# # EuroPython will be held in Italy in July 2017
#
# + General website open in January 2017

# %%
IFrame(src="http://www.europython-society.org/post/152466584224/europython-2017-will-be-held-in-rimini-italy", height=600, width=1024)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="http://www.europython-society.org/post/152466584224/europython-2017-will-be-held-in-rimini-italy"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # So ... we made an accounting error with PyData London 2016

# %% [markdown]
# We said that we had raised around ...
#
# ## ~£33,000

# %% [markdown]
# We actually made:

# %% [markdown]
# # ~£80,000

# %%
Image('images/pydata_london_accounts_2016.png', width=600)

# %% [markdown]
# # POTM - airflow <small>Airflow is a platform to programmatically author, schedule and monitor workflows</small>
#
# + The new hotness in data pipeline libraries
#
# > "more/better features (dashboard, scheduler, ...) and now
# > better community support, i.e. it's an apache project now"
# >
# > -- Marco Bonzanzini, Slack, November 2016

# %%
IFrame('http://pythonhosted.org/airflow/index.html', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="http://pythonhosted.org/airflow/index.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyData London 2017 ... it's on!
