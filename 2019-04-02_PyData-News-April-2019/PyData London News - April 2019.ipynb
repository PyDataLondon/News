# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo
default_size = {'width': 1024, 'height': 600}

# %% [markdown]
# # PyData London News <small>April 2019</small>
#
# ## 54th Meetup
#
# ## Host: Man AHL

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # PyData Code of Conduct
#
# - https://pydata.org/code-of-conduct/

# %%
IFrame('https://pydata.org/code-of-conduct/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://pydata.org/code-of-conduct/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyData
#
# + Educational program by NumFOCUS
# + A global community
# + 136 groups world-wide
# + 112,000+ users world-wide
# - https://www.meetup.com/pro/pydata/

# %%
Image('images/pydata-map.png', **default_size)

# %% [markdown]
# # PyData London
#
# + 9,400+ members
# + Monthly meetup and annual conference
# + All run by volunteers
# + https://london.pydata.org/

# %%
Image('images/pydata-london-screenshot.png', **default_size)

# %% [markdown]
# # Six easy ways to run your Jupyter Notebook in the cloud
#
# TLDR;
# * Binder
# * Kaggle Kernels
# * Google Colaboratory (Colab)
# * Microsoft Azure Notebooks
# * CoCalc
# * Datalore
#
# https://www.dataschool.io/cloud-services-for-jupyter-notebook/

# %%
IFrame("https://www.dataschool.io/cloud-services-for-jupyter-notebook/", **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://www.dataschool.io/cloud-services-for-jupyter-notebook/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyData London Conference - July 2019
# ### https://pydata.org/london2019
#
# + When? **12-14 July 2019** at the Tower Hotel (Tower Bridge)
# + CFP deadline: **19th April**
#
# ### What's on?
# + Friday tutorials, Saturday-Sunday keynotes and talks
#
# + Ticket sales open
# + Call for Sponsors
# + Beginners Bootcamp
# + Mentorship Programme for first-time speakers
# + Childcare support
# + Diversity tickets
# + Pub Quiz

# %%
Image('images/pydata-london-2019.png', **default_size)

# %% [markdown]
# # POTM: PyTorch <small>Deep-learning in Python</small>
#
# * https://pytorch.org/docs/stable/index.html
# * Deep-learning library for Python
# * "Python-first",
# * C++ front-end available

# %%
IFrame('https://pytorch.org/docs/stable/index.html', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://pytorch.org/docs/stable/index.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
