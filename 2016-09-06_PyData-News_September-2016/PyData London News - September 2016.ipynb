# %%
# import Image
from IPython.display import Image, HTML, IFrame, YouTubeVideo

# %% [markdown]
# # PyData London News <small> September 2016 </small>
# ## Wifi: GST-Man, pw:

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # JIT’ing TensorFlow in Python
#
# + Uses `llvmlite` to provide a simplified API to LLVM IR
# + LLVM allows you target lots of different backends - x86, CUDA, ARM.
# + Lovely and Pythonic! Which is a refreshing change from massive-multiline-string-C++

# %%
IFrame(src='http://blog.christianperone.com/2016/08/jit-native-code-generation-for-tensorflow-computation-graphs-using-python-and-llvm/', height=600, width=1000)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="http://blog.christianperone.com/2016/08/jit-native-code-generation-for-tensorflow-computation-graphs-using-python-and-llvm/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyData SF videos are up
#
# + PyDataTV channel has 48 videos!
# + Lots of good machine learning, data engineering and deep learning.
# + ... and of course an obligatory Julia presentation.

# %%
Image('images/playlist_pydata_SF_2016.png', height=600, width=1000)

# %% [markdown]
# # PyCon UK <small>Cardiff City Hall, from Thursday 15th to Monday 19th September.</small>
#
# + General python stuff
# + Stuff about the Microbit, Robots, Web dev

# %%
IFrame(src="http://2016.pyconuk.org/", height=600, width=1024)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="http://2016.pyconuk.org/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Stats?

# %%
Image('')

# %% [markdown]
# # POTM - llvmlite <small>A library that you might _actually_ want to use for using LLVM</small>
#
# + `llvmpy` contructs IR by calling the C++ libraries
# + `llvmlite` focuses on being able to stream annotated code in and get IR out.
# + Ergo, it's easier to use for JIT'ing.

# %%
IFrame('http://llvmlite.readthedocs.io/en/latest/', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="http://llvmlite.readthedocs.io/en/latest/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
