# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo

# %% [markdown]
# # PyData London News <small>December 2016</small>
# ## Wifi: GST-Man, pw: raspberry28

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # Python 3.6.0 - nearly there
#
# + Final version expected 16th Dec 2016
# + Asynchronous Generators / Asynchronous Comprehensions
# + f-strings
# + Syntax for variable annotations
# + ...
# + https://docs.python.org/3.6/whatsnew/3.6.html

# %%
IFrame(src='https://docs.python.org/3.6/whatsnew/3.6.html', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="https://docs.python.org/3.6/whatsnew/3.6.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Save the date - Next Meetup 10th January 2017
#
# + We're breaking our own "first Tuesday of the month" rule
# + It won't happen again (maybe)

# %% [markdown]
# # PyCon Italy, Florence
#
# + 6-9 April 2017
# + Nice PyData track
# + Ticket discount if you also go to DjangoCon Europe
# + https://www.pycon.it/en

# %%
IFrame(src='https://www.pycon.it/en', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="https://www.pycon.it/en"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # POTM - TrumpScript <small>Make Python Great Again!</small>
#
# + No float, only int. America never does anything halfway
# + No import statements. Only home-grown American code
# + It doesn't run on Windows (Trump doesn't believe in PC)
# + It doesn't run on macOS (until Apple gives cellphone info to autorities)
# + Flag `--Wall` (refuse to run on Mexican locales)
# + The code fails silently (Trump doesn't like to talk about his failures)
# + https://github.com/samshadwell/TrumpScript

# %%
IFrame(src='https://github.com/samshadwell/TrumpScript', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="https://github.com/samshadwell/TrumpScript"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyData London 2017
#
# + 5-7 May 2017
# + Bloomberg
# + Call for Proposals opens early January
# + Call for Volunteers (YOU!)
# + Call for Sponsors
# + http://pydata.org/london2017/

# %%
IFrame(src='http://pydata.org/london2017/', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="http://pydata.org/london2017/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # 2016 Review

# %% [markdown]
# + From ~2300 to ~4500 meetup members

# %% [markdown]
# + We donated ~£80,000 to NumFOCUS (if you trust our accountants...)

# %% [markdown]
# + PyData YouTube channel: we have the most trafficked playlist!

# %% [markdown]
# + Hundreds of speakers and volunteers. Thank You!
