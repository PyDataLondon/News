# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo
default_size = {'width': 1024, 'height': 600}

# %% [markdown]
# # PyData London News <small>March 2018</small>
# ## Wifi: GST-Man, pw: xxx

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # Pandas Documentation Sprint
#
# + Saturday 10th March, from 10am
# + 30+ locations world wide
# + London chapter by Python Sprints, hosted at Bloomberg
# + https://python-sprints.github.io/pandas/

# %%
IFrame('https://python-sprints.github.io/pandas/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://python-sprints.github.io/pandas/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # More PyData in the UK
#
# + [PyData Bristol meetup](https://www.meetup.com/PyData-Bristol/) launched on 15th Feb, first meetup 15th March
# + [PyData Edinburgh meetup](https://www.meetup.com/PyData-Edinburgh/) The first meetup was on 1st Feb
# + [PyData Cardiff meetup](https://twitter.com/pydatacardiff)

# %%
Image('images/pydata-bristol.png', **default_size)

# %% [markdown]
# # New Python conference: PyLondinium
#
# + Supported by PSF
# + 8-10 June (Fri sprints, Sat-Sun talks)
# + Call for Proposals now open
# + https://pylondinium.org/

# %%
IFrame('https://pylondinium.org/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://pylondinium.org/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # AHL Hackathon
#
# + https://www.ahl.com/hackathon
# + Hackathon to improve the Python Data Science
# + **21-22 April** hosted by AHL

# %%
Image('images/ahl-hackathon.png', **default_size)

# %% [markdown]
# # PyData London 2018
#
# + https://pydata.org/london2018/
# + **27-29 April 2018** at the **Tower Hotel**
# + Fri: Tutorials; Sat-Sun: main event
# + 3 parallel tracks, 1 unconference track (hackathon, sprints, etc.)
# + Tickets now for sale

# %%
Image('images/pydata_2018.png', **default_size)

# %% [markdown]
# ## PyData London 2018 - Keynote Speakers

# %%
Image('images/keynote-speakers.png', **default_size)

# %% [markdown]
# ## More on PyData London 2018
#
# + Proposals under review, programme schedule by the end of March
# + Diversity Scholarship: [applications open](https://pydata.org/london2018/about/diversity-scholarships/)
# + Childcare support
# + Call for Volunteers (talk to Agata!)
# + Unconference activities (TBC):
#     - Algorithmic Art Hackathon (Tariq Rashid)
#     - Politics Hackathon (John Sandall)
#     - pandas sprint (Marc Garcia)
# + Call for Sponsors

# %% [markdown]
# # POTM: JupyterLab <small>Next-generation web-based interface for Jupyter</small>
#
# + IDE for working with notebooks, code and data
# + Lightning talk later (thanks Steve!)

# %%
Image('images/jupyterlab.png', **default_size)
