# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo
default_size = {'width': 1024, 'height': 600}

# %% [markdown]
# # PyData London News <small>December 2018</small>
#
# ## 51st Meetup
#
# ## Host: Man AHL

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # PyData
#
# + Educational program by NumFOCUS
# + A global community
# + 123 groups world-wide
# + 100,000+ users world-wide
# - https://www.meetup.com/pro/pydata/

# %%
Image('images/pydata-map.png', **default_size)

# %% [markdown]
# # PyData London
#
# + 8,600+ members
# + monthly meetup and annual conference
# + All run by volunteers
# + https://london.pydata.org/

# %%
Image('images/pydata-london-screenshot.png', **default_size)

# %% [markdown]
# # NumFOCUS
#
# + US-based charity in support of open-source scientific computing
# + Financial/admin support for many open-source projects
# + Support for many community events
# + https://numfocus.org/

# %%
Image('images/numfocus.png', **default_size)

# %% [markdown]
# # Fundraising for Ray Donnelly
#
# + https://www.gofundme.com/arku72-help-ray-fight-cancer?pc=&rcid=r01-154276953186-9a305845a7bc4a29

# %%
IFrame('https://www.gofundme.com/arku72-help-ray-fight-cancer?pc=&rcid=r01-154276953186-9a305845a7bc4a29', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://www.gofundme.com/arku72-help-ray-fight-cancer?pc=&rcid=r01-154276953186-9a305845a7bc4a29"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyCon Italy - May 2019
#
# + https://www.pycon.it/en/
# + 2-5 May in Florence, Italy
# + **CfP open until 6th January**
# + Multiple tracks, including PyData

# %%
Image('images/pycon-italy.png', **default_size)

# %% [markdown]
# # ... PyData London - July 2019 !!!
#
# + **12-14 July 2019** at the Tower Hotel (Tower Bridge)
# + Friday tutorials, Saturday-Sunday keynotes and talks
#
#
# + Beginners Bootcamp
# + Mentorship Programme for first-time speakers
# + Childcare support
# + Diversity tickets
# + Pub Quiz

# %% [markdown]
# # POTM: pyjanitor <small>Data wrangling in pandas</small>
#
# + https://pyjanitor.readthedocs.io/
# + Simple API for data wrangling on pandas objects
# + Cleaning column names
# + Identifying duplicates
# + Removing emtpy rows/columns
# + ... many more data cleaning functionalities

# %%
IFrame('https://pyjanitor.readthedocs.io/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://pyjanitor.readthedocs.io/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
