# %%
# import Image
from IPython.display import Image, HTML, IFrame

# %% [markdown]
# # Wifi network: GST-MAN
# # Wifi password: lychee79

# %% [markdown]
# # PyData London News <small> September 2015 </small>

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # EuroScipy Report
#
# ## ~ 200 folk attending
# ## Very high quality talks on Visualisation and Reproducibility
# ## Applications to astrodynamics, chemistry, biology, etc...
# ## _"Python 2 is Legacy Python"_

# %%
Image('images/euroscipy.jpg')

# %% [markdown]
# # Upcoming conference reminders
#
# ## EA*R*L (Effective Applications of the *R* Language) Conference _14-16th September_
#
# ## PyCon UK Science track _19th - 21st September_
#
# ## Budapest BI - Keynotes by Wes McKinney and Ian Ozsvald _13th-15th October_

# %% [markdown]
# # PyCon Ireland <small>October 24th - 26th</small>
#
# ## PyCon Ireland is back!
# ## This year the conference will be held on Sat 24th - Sun 25th October in the Radisson Blu Royal Hotel in Dublin.
# ##The format will consists of two tracks of talks along with two tracks of workshops.
# ## https://python.ie/pycon-2015/
# ## Tickets now on sale: https://ti.to/python-ireland/pycon-ireland-2015

# %% [markdown]
# # Towards 2000 members!

# %%
Image(filename="images/PyData-London-Meetup_Member_List_on_09-01-15.png")

# %% [markdown]
# ## Looking for more speakers and lightning talks - come and talk to us!

# %% [markdown]
# # IPython 4.0 released!
# ## Significant refactor, completing the transition of language-agnostic parts to Jupyter!
#
# ## `$ conda update ipython`
#
# ## Notebook Extension API changed - go back to 3 if you have trouble:
#
# ## `$ conda create -n ipy3env python=3.4 numpy=1.9 ipython-notebook=3`

# %% [markdown]
# # POTM, Recipy - an effortless method to record provenance in Python
# ## Winner of the Best Talk at Euroscipy
# ## Monkey patches things like mpl and Pandas to log what you did and make a graph
# ## All powered by a single import
# ## https://github.com/recipy/recipy

# %%
Image(filename='images/recipy-example.png')

# %%
Image(filename='images/recipy.png')
