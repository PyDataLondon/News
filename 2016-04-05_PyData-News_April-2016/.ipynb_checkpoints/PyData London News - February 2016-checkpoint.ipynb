# %%
# import Image
from IPython.display import Image, HTML, IFrame, YouTubeVideo

# %% [markdown]
# # PyData London News <small> February 2016 </small>

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # Complexity of Python Operations <small>University of California, Irvine</small>

# %% [markdown]
# + https://www.ics.uci.edu/~pattis/ICS-33/lectures/complexitypython.txt
# + Details the Big-O complexity of various Python data structures

# %%
IFrame('https://www.ics.uci.edu/~pattis/ICS-33/lectures/complexitypython.txt', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.ics.uci.edu/~pattis/ICS-33/lectures/complexitypython.txt"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # pydata.org/london2016/cfp/

# %% [markdown]
# + Call for proposals for PyData London 2016!
# + 11 submission so far.
# + Review committee of 12 is ready to rock.

# %%
Image('images/pydatalondon_cfp.png', width=800, height=600)

# %% [markdown]
# # PyDataAmsterdam  <small>12th - 13th March</small>
#
# * CFP is open
# * All Proposals are due by 14 February 2016

# %%
Image(filename='images/pydataamsterdam_cfp.png')

# %% [markdown]
# # PyData Members are generally professionals or being on the frontpage of Meetup.com matters

# %%
Image('images/Day of the week people joined on 2016-02-02.png', width=800, height=600)

# %% [markdown]
# # POTM - SymPy <small>Algebraic expressions in Python</small>

# %%
IFrame('http://docs.sympy.org/latest/tutorial/intro.html', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="http://docs.sympy.org/latest/tutorial/intro.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame('http://podcastinit.com/aaron-meurer-sympy.html', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="http://podcastinit.com/aaron-meurer-sympy.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
