# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo
default_size = {'width': 1024, 'height': 600}

# %%
Image(filename="../utils/images/pydata_logo.png", width='300px')

# %% [markdown]
# # PyData London<small> February 2026</small>
#
# ### **104th** Meetup, hosted by Man Group
#
# ### [@pydatalondon.bsky.social](https://bsky.app/profile/pydatalondon.bsky.social)

# %% [markdown]
# ## PyData Code of Conduct
#
# ### https://pydata.org/code-of-conduct/

# %%
IFrame('https://pydata.org/code-of-conduct/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://pydata.org/code-of-conduct/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## NumFOCUS
#
# - US-based charity in support of open-source scientific computing
# - Financial and admin support for many open-source projects
# - Support for many community events
# - https://numfocus.org

# %%
IFrame('https://numfocus.org/sponsored-projects', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://numfocus.org/sponsored-projects"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## PyData
#
# + Educational program by NumFOCUS
# + A global community
# + 135 groups across 56 countries world-wide
# + 215,000+ users world-wide (+23,000 per year!)
# + https://www.meetup.com/pro/pydata/

# %%
IFrame('https://hevansdev.github.io/mapping-pydata/pydata_world_map.html#1/-35.4607/-33.7500', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://hevansdev.github.io/mapping-pydata/pydata_world_map.html#1/-35.4607/-33.7500"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame('https://hevansdev.github.io/mapping-pydata/pydata_world_map.html#6/54.5000/-2.0000', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://hevansdev.github.io/mapping-pydata/pydata_world_map.html#6/54.5000/-2.0000"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## PyData London
#
# + 16,000+ members running a monthly meetup and annual conference
# + All run by volunteers
# + Propose a Talk: https://london.pydata.org/submit-a-talk/

# %%
Image('../utils/images/pydata-london-screenshot.png', width=600, height=400)

# %% [markdown]
# ## Upcoming Conferences
#
# ### Courtesy of https://pythondeadlin.es/

# %%
IFrame('https://pythondeadlin.es/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://pythondeadlin.es/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
Image('../utils/images/pydata_global_2025.png', width=800, height=600)

# %% [markdown]
# ## Tonight's Schedule
#
# #### 18:30 Doors open
# #### 19:00 Introduction ⬅️ **YOU ARE HERE**
# #### 19:15 Main Talk #1 & Q&A &rarr; *SVD-ROM: Reduced Order Modeling of huge arrays using the Singular Value Decomposition* — David Salvador-Jasin
# #### 20:00 Break + Networking 🥂
# #### 20:20 Main Talk #2 & Q&A &rarr; *From Zero to HyperPod: Cutting Infrastructure Complexity for Distributed Model Training on AWS* — Anton Nazaruk
# #### 20:50 ⚡ Lightning Talk⚡  &rarr; *Agentic, Agentic AI for Personalized Care — Lessons & Challenges from Holisticare.io* — Mojtaba
# #### 20:55 ⚡ Lightning Talk⚡  &rarr; *Mapping the International PyData Community featuring Web Scraping and Data Wrangling* — Hugh Evans
# #### 21:00 We're done 🔜 The Banker 🍻
