# %%
# import Image
from IPython.display import Image, HTML, IFrame, YouTubeVideo

# %% [markdown]
# # PyData London News <small> November 2015 </small>

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # Budapest BI <small>13th - 15th October</small>
#
# * Keynotes by Wes McKinney and Ian Ozsvald

# %%
Image(filename='images/trabants.jpg')

# %% [markdown]
# # PyCon IE <small>24th - 25th October</small>
#
# * Audience Experience?

# %% [markdown]
# # Upcoming conference reminders
#
# ## PyHPC at Supercomputing 15 <small>15th November</small>
#
# * Schedule: http://lanyrd.com/2015/pyhpc2015/
# * Proceedings to be published
# * Python Performance optimisation tools and libraries
# * Applications: NLP, Large-scale optimisation problems, sample identification using PySpark
# * Experience reports using Python in HPC at TACC
# * dispel4py: A Python framework for data-intensive science

# %% [markdown]
# # PyData London survey!
#
# * We need more responses!
# * https://www.surveymonkey.com/r/288CGGR

# %% [markdown]
# ## Most requested talk topics
# * Machine Learning
# * Exploratory data analysis
# * Medium data
# * Deep nets

# %% [markdown]
# ## Most requested lightning talk topics
# * Statistics
# * Spark
# * Visualisation techniques

# %% [markdown]
# # Python 3.5 / IPython 4.0

# %%
Image(filename='images/python35_ipython.png')

# %% [markdown]
# # Matplotlib 1.5 released!
#
# * Python 3.5 support
# * Plot methods can take labelled data - e.g. pandas DataFrames
# * Better date/time axis labels
# * New colormaps, new styles, many from Seaborn

# %%
Image(filename='images/colormaps.png')

# %% [markdown]
# # POTM, PyScaffold
#
# * Generate boilerplate package easily
#
# ```
# $ putup gap
#
# $ cd gap
#
# $ ls
#
# AUTHORS.rst  docs  LICENSE.txt  requirements.txt  setup.py
# CHANGES.rst  gap   README.rst   setup.cfg         tests
#
# $ cat AUTHORS.rst
#
# * Graham Markall <graham.markall@continuum.io>
#
# $ git log
#
# commit d4f020e112156b6ca3966438c5d47c2125ddc791
# Author: Graham Markall <graham.markall@continuum.io>
# Date:   Mon Nov 2 19:44:04 2015 +0000
#
#     Initial commit
#
# ```

# %%
Image(filename='images/gapdocs.png')

# %% [markdown]
# ```
# --with-django
#
# --with-travis
#
# --with-pre-commit
#
# --with-tox
#
# --with-numpydoc
#
# --license # 'mit', 'gpl2', 'new-bsd', 'apache'...
# ```

# %% [markdown]
# # PyData Conference 2015 Videos! <small> Well ... 90.4% are </small>
#
# * PyDataTV Youtube Channel
# * Playlist "PyData London 2015" https://www.youtube.com/playlist?list=PLGVZCDnMOq0q6hrjJA56bq18eHtGusYJK

# %%
Image('images/pydata_conf_playlist.png')

# %%
YouTubeVideo('Yqy1F4fs1k0',600,400)
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://www.youtube.com/embed/Yqy1F4fs1k0"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
YouTubeVideo('T138eQjEASs', 600, 400)
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://www.youtube.com/embed/T138eQjEASs"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
YouTubeVideo('-LDXqGFD-Qw', 600, 400)
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://www.youtube.com/embed/-LDXqGFD-Qw"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
