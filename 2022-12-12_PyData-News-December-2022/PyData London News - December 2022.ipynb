# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo
default_size = {'width': 1024, 'height': 600}

# %%
Image(filename="images/pydata_logo.png", width='300px')

# %% [markdown]
# # PyData London News <small>December 2022</small>
#
# ### 69th Meetup, hosted by Man Group
#
# ### @PyDataLondon

# %% [markdown]
# # PyData Code of Conduct
#
# ### https://pydata.org/code-of-conduct/

# %%
IFrame('https://pydata.org/code-of-conduct/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://pydata.org/code-of-conduct/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # NumFOCUS
#
# - US-based charity in support of open-source scientific computing
# - Financial and admin support for many open-source projects
# - Support for many community events
# - https://numfocus.org

# %%
Image('images/numfocus.png', **default_size)

# %% [markdown]
# # PyData
#
# + Educational program by NumFOCUS
# + A global community
# + 215 groups world-wide (+14 since May 2022!) 🇳🇿🇳🇿🇳🇿
# + 203,000+ users world-wide (+13000 since May 2022!)
# - https://www.meetup.com/pro/pydata/

# %%
Image('images/pydata-map.png', **default_size)

# %%
Image('images/pydata-uk-map.png', **default_size)

# %% [markdown]
# # PyData London
#
# + 11,600+ members (Approx +100 members/month, we can do better! Tell a friend! Submit a talk!)
# + Monthly meetup and annual conference
# + All run by volunteers
# + https://london.pydata.org/
#
#
# + Propose a Talk: https://london.pydata.org/submit-a-talk/

# %%
Image('images/pydata-london-screenshot.jpg', **default_size)

# %% [markdown]
# # We're back!
# - 2 years older, a little rustier but as keen as ever
# - Thanks for MAN AHL for continuing to fund this
# - Thank you all for coming along, and the speakers we have this evening
#
#
# ## Man Group
# 1. The world's largest publicly traded hedge fund company with $151 billion in funds under management as of March 2022.
# 2. 100 open positions in both tech and research.
# 3. Sponsors: "**The Man Booker Prize**" and "**PyData London**"

# %% [markdown]
# # PyData London 2022 - May 17-19th
#
# #### https://pydata.org/london2020/
# #### Venue: the Tower Hotel on St. Katharine's Docks
# #### Tutorials on Friday
# #### Keynotes, talks and more on Saturday-Sunday
# #### Free childcare support
# #### Diversity scholarships
# #### All proceeds benefit NumFOCUS

# %%
Image('images/pydata_london_2022.jpg', **default_size)

# %% [markdown]
# # PyData London 2023 - June 2nd - 4th
#
# #### Venue: the Tower Hotel on St. Katharine's Docks
# #### Tutorials on Friday
# #### Keynotes, talks and more on Saturday-Sunday
# #### Free childcare support
# #### Diversity scholarships
# #### All proceeds benefit NumFOCUS

# %% [markdown]
# # Upcoming Conferences & Events
#
# ### 🇮🇱 Dec 13th 2022 = **PyData Tel Aviv 2022** (Israel)
# ### 🐍 Thu 15th December = **PyData Bristol**
# ### 🐍 Tue 10th January = ⭐ **PyData London** (70th Meetup) ⭐

# %% [markdown]
# # Thu 15th December 2022 - NormConf
#
# IFrame('https://normconf.com/', **default_size)

# %% [markdown]
# # POTM (Package Of The Month)

# %%
Image('images/email-santa.png', **default_size)

# %%
from emailsanta import SantaEmail, SantaReply

letter_to_send = SantaEmail(
    "John",             # name
    1,                  # gender (in this case it is boy)
    34,                 # age
    "London",           # city
    "United Kingdom",   # country
    3,                  # how good have you been? (in this case it's really really good!)
    "electric snoodie", # your first present
    "carrots",          # your second present
    "lego",             # your third present
    comment="Hi Santa!.",    # any additional comments for Santa
)

# %%
my_reply = SantaReply(letter_to_send)   # get your reply "from Santa"!
print(my_reply.replyText)               # this prints the plaintext reply
# Out:
#
# London, United Kingdom
#
#
# Tuesday, August 1, 2023
#
# #1, Rudolph Way
# Reindeerland, North Pole
# SAN TA1
#
#
# Hello John!!
#
# The elves and I are so excited your letter is here. You are one of our favourite boys in London after all! When your letter arrived, a bunch of the elves scurried to the big computer screen and started jumping and dancing. Mrs Claus and I always go to see the big 🎄 tree 🎄 lighting in Trafalgar Square. That is one BIG Christmas tree! I know the elves are really glad they don't have to decorate that one! The Internet sure is wonderful because now I never feel lonely all the way up at the North Pole. I can get those wonderful Christmas letters any time of the year now, but it's always special when I get one from you, John.
#
# ...

# %% [markdown]
# # CFPOTM (CFP Of The Month)
# ## [Python Deadlin.es](https://pythondeadlin.es/)

# %%
IFrame('https://pythondeadlin.es/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://pythondeadlin.es/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Tonight's Schedule
#
# #### 18:30 Doors open
# #### 19:00 Talks start ⬅️ **YOU ARE HERE**
# #### 19:15 What's the Itch That Feature Stores Scratch? — Moritz Meister
# #### 19:45 Break 🥂
# #### 20:00 Using BERT for Stable, Dynamic Topic Detection — Matt Hobby
# #### 20:30 ⚡ Lightning Talks ⚡ + 📣 Community Announcements 📣
# #### 20:45 to 21:00 We're done 🔜 The Oyster Shed 🍻

# %% [markdown]
# ### What's the Itch That Feature Stores Scratch? — Moritz Meister
#
# Do you actually need a feature store for machine learning (ML)? Many individuals and organizations ask themselves this question, and many come to different conclusions. In this talk, we will clearly define how a feature store solves problems such as training-inference skew for operational ML systems, reuse of pre-computed features across multiple models, and the integration of historical and contextual data into online models. However, there are also scenarios where you do not need a feature store. For example, if you have a batch system processing data in a data warehouse and the features are reused in other models. We will try to give an honest appraisal of when you should reach for the feature store tool, and when to leave well alone.

# %% [markdown]
# ### Using BERT for Stable, Dynamic Topic Detection — Matt Hobby
#
# BERT and other transformer models have revolutionised NLP and high dimensional representation of semantic meaning.
# In this talk we discuss the use of BERT embeddings to detect topics in documents. We demonstrate that the combination of BERT embeddings with network community detection methods provides a stable means of detecting topics where the number of topics apriori is unknown, this overcoming one of major shortcomings of LDA.
#
# We highlight the stability of the methodology when compared to the approach taken by the popular BERTopic GitHub repository. Furthermore, we demonstrate how this approach can be used for dynamic topic modelling.

# %% [markdown]
# ## ⚡ Lightning Talk ⚡
# ### 🧀🧠 The Chemically Induced Christmas Experience — Emlyn Clay
