# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo
default_size = {'width': 1024, 'height': 600}

# %% [markdown]
# <!-- deck-local-overflow-fix -->
# <style>
# .reveal .slides section { overflow: hidden !important; }
# .reveal .slides section h4 { font-size: 0.9em; line-height: 1.15; }
# </style>

# %% [markdown]
# <img src="../utils/images/pydata_logo.png" width="300px" />

# %% [markdown]
# # PyData London<small> May 2026</small>
#
# ### 107th Meetup, hosted by Man Group
#
# ### [@pydatalondon.bsky.social](https://bsky.app/profile/pydatalondon.bsky.social)

# %% [markdown]
# ## PyData Code of Conduct
#
# ### Be thoughtful. Be kind to each other.
#
# **https://pydata.org/code-of-conduct/**

# %% [markdown]
# ## PyData
#
# + Educational program of **NumFOCUS** — the charity behind NumPy, pandas, Jupyter and friends
# + A global community: **121 groups across 51 countries** on Meetup (plus more off-platform)
# + **209,000+ members** worldwide
# + https://www.meetup.com/pro/pydata/ &nbsp;·&nbsp; https://numfocus.org

# %% [markdown]
# <img src="../utils/images/pydata-uk-map-2025.png" width="600" height="400" alt="UK PyData map" />

# %% [markdown]
# ## PyData London
#
# + **16,290 members** and growing — monthly meetup + annual conference
# + All run by volunteers
# + Propose a talk: https://london.pydata.org/submit-a-talk/

# %% [markdown]
# <img src="../utils/images/pydata-london-screenshot.png" width="600" height="400" alt="PyData London screenshot" />

# %% [markdown]
# ## UK PyData Meetups — May 2026
#
# - **Wed 6 May** — PyData Exeter #13 _(Open Source Community Talks, Innovation Hub)_
# - **Thu 7 May** — PyData Cornwall #4 _(Data Engineering Edition, Newquay)_
# - **Fri 22 May** — PyData Wolverhampton _(Python for Data Collection)_
# - **Thu 28 May** — PyData Manchester _(Krakenflex, Circle Square)_
# - **Fri 29 May** — PyData Bradford _(Bradford Mechanics' Institute Library)_
#
# **PyData Bristol** — looking for a new sponsor / venue. **If you can help, grab John after the talks!**

# %% [markdown]
# ## Since We Last Met
#
# ### **Python 3.14.4** shipped 7 April
#
# Bugfix-only maintenance release — but a useful nudge that **3.14 is the first version with free-threaded (no-GIL) CPython officially supported** via PEP 779.
#
# _If you've been waiting to try it, now's the time._
#
# https://www.python.org/downloads/release/python-3144/

# %% [markdown]
# ## Tonight's Speakers
#
# - **Robin Linacre** — _Rapid deduplication and fuzzy matching of large datasets using Splink_
# - **Filip Makraduli** — _Small Model Inference Infrastructure: Lessons Beyond vLLM_
# - **Ian Ozsvald** — _Build your own LLM, Live, with MicroGPT_

# %% [markdown]
# ## Tonight's Schedule
#
# - **18:30** Doors open
# - **19:00** Introduction <- **YOU ARE HERE**
# - **19:15** Main Talk #1 & Q&A -> Rapid deduplication and fuzzy matching of large datasets using Splink - Robin Linacre
# - **19:45** Break + Networking
# - **20:00** Main Talk #2 & Q&A -> Small Model Inference Infrastructure: Lessons Beyond vLLM - Filip Makraduli
# - **20:30** Main Talk #3 & Q&A -> Build your own LLM, Live, with MicroGPT - Ian Ozsvald
# - **21:00** We're done -> The Banker

# %% [markdown]
# ## Upcoming Conferences
#
# ### Courtesy of https://pythondeadlin.es/

# %% [markdown]
# <iframe src="https://pythondeadlin.es/" width="1024" height="600" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# ## Got something to share?
#
# ### We're always looking for speakers — beginners welcome.
#
# **https://london.pydata.org/submit-a-talk/**
#
# _Lightning talks (5 min) and full talks (~30 min) both welcome._

# %% [markdown]
# <!-- conference slide: full-bleed promo image -->
# <style>
# .reveal section.conf-slide { padding: 0 !important; }
# .reveal section.conf-slide img { width: 100%; height: auto; display: block; margin: 0 auto; }
# </style>
# <div class="conf-slide" style="text-align:center;">
# <img src="../utils/images/pydata-london-2026.jpg" style="width:100%;height:auto;" alt="PyData London 2026 — Fri 5 - Sun 7 June, Convene Sancroft, St. Paul's. Book at https://ti.to/pydata/pydatalondon26" />
# <p style="margin-top:0.4em;"><em>No regular meetup in June — but PyData Surrey is running a satellite!</em></p>
# </div>

# %% [markdown]
# ## Coming as a team? Save up to 15%
#
# <div style="display:flex;gap:1.2em;justify-content:center;margin:0.6em 0 0.8em;">
#   <div style="flex:1;max-width:340px;border:3px solid #ee9c2d;border-radius:14px;padding:0.7em 1em;text-align:center;">
#     <div style="font-size:0.75em;color:#666;text-transform:uppercase;letter-spacing:0.05em;">Group of 3+</div>
#     <div style="font-size:2.4em;font-weight:bold;color:#ee9c2d;line-height:1;margin:0.15em 0;">10% off</div>
#     <div style="font-size:1.1em;"><strong>£781.88</strong> <span style="color:#666;">/ ticket</span></div>
#     <div style="font-size:0.75em;color:#888;">save ~£94 each</div>
#   </div>
#   <div style="flex:1;max-width:340px;border:3px solid #2eb5b5;border-radius:14px;padding:0.7em 1em;text-align:center;">
#     <div style="font-size:0.75em;color:#666;text-transform:uppercase;letter-spacing:0.05em;">Group of 5+</div>
#     <div style="font-size:2.4em;font-weight:bold;color:#2eb5b5;line-height:1;margin:0.15em 0;">15% off</div>
#     <div style="font-size:1.1em;"><strong>£744.35</strong> <span style="color:#666;">/ ticket</span></div>
#     <div style="font-size:0.75em;color:#888;">save ~£131 each</div>
#   </div>
# </div>
#
# <div style="font-size:0.7em;line-height:1.4;color:#444;text-align:center;margin-top:0.5em;">
# <em>For comparison — Individual 3-Day £500.40 &nbsp;·&nbsp; Student 3-Day £287.73 &nbsp;·&nbsp; Single-day passes from £106.34. All prices include VAT &amp; fees.</em>
# </div>
#
# ### **Book at https://ti.to/pydata/pydatalondon26**
