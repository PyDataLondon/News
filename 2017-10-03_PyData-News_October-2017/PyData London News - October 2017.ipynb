# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo
default_size = {'width': 1024, 'height': 600}

# %% [markdown]
# # PyData London News <small>October 2017</small>
# ## Wifi: GST-Man, pw: ?????

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # Python 3.7 - First Alpha
#
# + First Alpha version just released
# + Final Version expected 2018-06-15
# + ... nothing much to say yet
# + https://docs.python.org/3.7/whatsnew/3.7.html
# + https://www.python.org/dev/peps/pep-0537/

# %%
IFrame(src='https://docs.python.org/3.7/whatsnew/3.7.html', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://docs.python.org/3.7/whatsnew/3.7.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyCon UK in Cardiff 26-30 October
#
# + Annual gathering of the UK Python community and friends
# + PyData track for the first time
# + http://2017.pyconuk.org/
# + Preliminary schedule is up!

# %%
IFrame('http://2017.pyconuk.org/schedule/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="http://2017.pyconuk.org/schedule/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Python Developers Survey 2017
#
# + Partnership between the PSF and JetBrains
# + Shed some light on how different Python developers use Python and related tools
# + 100 randomly chosen winners of a Python Surprise Gift Pack
# + https://surveys.jetbrains.com/s3/c7-python-developers-survey-2017

# %%
IFrame('https://surveys.jetbrains.com/s3/c7-python-developers-survey-2017', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://surveys.jetbrains.com/s3/c7-python-developers-survey-2017"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # New meet-up group: Python Sprints
#
# + Hands-on meet-up, focus on contributing to Open Source
# + Open to all levels
# + Core developers joining the sprints remotely or in person
# + https://www.meetup.com/Python-Sprints/

# %%
# meetup.com blocks iframes?
# IFrame('https://www.meetup.com/Python-Sprints/', **default_size)
Image(filename="images/python-sprints-screenshot.png", **default_size)

# %% [markdown]
# # POTM - python-statsd <small>python client for statsd</small>
#
# + `statsd` is UDP proxy for a monitoring tool
# + ... often  this monitoring tool is graphite.
# + Really nice way of timing your functions in production.

# %%
IFrame(src='https://python-statsd.readthedocs.io/en/latest/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://python-statsd.readthedocs.io/en/latest/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
