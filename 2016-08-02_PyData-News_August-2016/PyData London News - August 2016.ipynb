# %%
# import Image
from IPython.display import Image, HTML, IFrame, YouTubeVideo

# %% [markdown]
# # PyData London News <small> August 2016 </small>
# ## Wifi: GST-Man, pw:

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # IPython 5.0.0 LTS released
#
# + `prompt_toolkit` replaces GNU `readline`
# + Last release for Python 2, IPython 6.x _requires_ Python 3
# + Rich documentation experimental functionality

# %%
IFrame(src='http://blog.jupyter.org/2016/07/08/ipython-5-0-released/', height=600, width=1000)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="http://blog.jupyter.org/2016/07/08/ipython-5-0-released/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Jupyter Lab — Alpha
#
# + It's an IDE in a browser
#     - A notebook
#     - A file manager
#     - A text editor
#     - A terminal emulator
#     - A monitor for running Jupyter processes
# + Built on PhosphorJS

# %%
IFrame(src='http://blog.jupyter.org/2016/07/14/jupyter-lab-alpha/', height=600, width=1000)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="http://blog.jupyter.org/2016/07/14/jupyter-lab-alpha/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src='https://phosphorjs.github.io/examples.html', height=600, width=1024)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://phosphorjs.github.io/examples.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyData EuroPython <small>July 14 - 24</small>
#
# + Did anyone go?
# + What happened?

# %%
IFrame(src='http://ep2016.europython.eu/en/events/pydata/', height=600, width=1024)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="http://ep2016.europython.eu/en/events/pydata/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
Image('images/LIGO_keynote.png')

# %% [markdown]
# # PyCon UK <small>Cardiff City Hall, from Thursday 15th to Monday 19th September.</small>
#
# + General python stuff
# + Stuff about the Microbit, Robots, Web dev

# %%
IFrame(src="http://2016.pyconuk.org/", height=600, width=1024)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="http://2016.pyconuk.org/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyCon Ireland <small>November 2016</small>
#
# + CfP closes in 2 weeks - https://python.ie/pycon-2016/call-proposals/

# %%
Image('images/pycon_ireland.png')

# %% [markdown]
# # 3700 members, woo!

# %%
Image('images/CDF of when members joined 2016-08-02.png')

# %% [markdown]
# # POTM - words2map <small>A visualisation tool for word clusters</small>
#
# + word2vec -> t-SNE -> HDBSCAN and then a pretty picture!
# + Made by yhat

# %%
IFrame('http://blog.yhat.com/posts/words2map.html', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="http://blog.yhat.com/posts/words2map.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
