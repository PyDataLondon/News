# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo
default_size = {'width': 1024, 'height': 600}

# %% [markdown]
# # PyData London News <small>June 2018</small>
# ## Wifi: GST-Man, pw: xxx

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # So ... PyData London 2018 was great!
#
# + 550 attendees (700 tickets between tutorials and main event)
# + 4 keynotes, 12 tutorials, 36 talks, lightning talks
# + 3 hackathons, Unconference, Diversity Round Table, Social Event + Pub Quiz
# + Beginners Bootcamp on Thursday (thanks Conrad!)
# + On-site Childcare support for the first time
# + Videos are on-line! https://www.youtube.com/user/PyDataTV

# %% [markdown]
# # ... and we raised $120,000 for NumFOCUS
#
# + Thanks to sponsors, speakers, reviewers, volunteers, attendees
#
#
# + NumFOCUS: a US-based 501(c)(3) public charity (https://www.numfocus.org/)
# + NumFOCUS supports open-source scientific computing projects
# + PyData: an educational program by NumFOCUS

# %% [markdown]
# # New Python conference: PyLondinium
#
# + Supported by PSF
# + 8-10 June (Fri sprints, Sat-Sun talks)
# + Tickets still available?
# + https://pylondinium.org/

# %%
IFrame('https://pylondinium.org/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://pylondinium.org/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyCon UK 2018 in Cardiff
#
# + 15-19 September in Cardiff https://2018.pyconuk.org/
# + **Call for Proposals ends 15 June**

# %%
Image('images/pyconuk.png', **default_size)

# %% [markdown]
# # EuroPython 2018 in Edinburgh
#
# + https://ep2018.europython.eu/en/
# + 23-29 July in Edinburgh
# + Mon-Tue: trainings; Wed-Fri: talks; Sat-Sun: sprints
# + Tickets now for sale

# %%
Image('images/europython.png', **default_size)

# %% [markdown]
# # POTM: pomegranate <small>fast and flexible probabilistic models</small>
#
# + Probability distributions
# + Markov chains
# + Bayesian Networks, Bayes classifiers
# + Support for: Out-of-core learning, mini-batch, parallelism, ...

# %%
IFrame('http://pomegranate.readthedocs.io/en/latest/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="http://pomegranate.readthedocs.io/en/latest/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
