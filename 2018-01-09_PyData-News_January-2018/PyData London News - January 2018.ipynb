# %%
# import Image
from IPython.display import display, Image, HTML, IFrame, YouTubeVideo
default_size = {'width': 1024, 'height': 600}

# %% [markdown]
# # PyData London News <small>January 2018</small>
# ## Wifi: GST-Man, pw: xxx

# %%
Image(filename="images/pydata_logo.png", width=600)

# %% [markdown]
# # The decorators they won't tell you about
#
# + https://github.com/hchasestevens/hchasestevens.github.io/blob/master/notebooks/the-decorators-they-wont-tell-you-about.ipynb

# %%
Image('images/decorators.png', **default_size)

# %% [markdown]
# # Save the Date: AHL PyData-themed Hackathon
#
# + 21-22 April 2018
# + Purpose: enhancing Python open-source software and improving the overall Python data science landscape

# %%
Image('images/ahl.png', **default_size)

# %% [markdown]
# # More PyData in the UK
#
# + Following the successful PyData track at PyCon UK
# + [PyData Bristol meetup](https://www.meetup.com/PyData-Bristol/)
# + [PyData Edinburgh meetup](https://www.meetup.com/PyData-Edinburgh/)

# %%
IFrame(src="https://www.meetup.com/PyData-Bristol/", **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://www.meetup.com/PyData-Bristol/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src="https://www.meetup.com/PyData-Edinburgh/", **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://www.meetup.com/PyData-Edinburgh/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # PyData London 2018!

# %% [markdown]
# # PyData London 2018
#
# + **27-29 April 2018**
# + New venue: the Tower Hotel (Toer Bridge)
# + Fri: Tutorials; Sat-Sun: main event
# + 3 parallel tracks, 1 unconference track (hackathon, sprints, etc.)
# + Beginner's Bootcamp on Wed-Thur
# + Mentorship Programme: we want new speakers!
# + Call for Sponsorship

# %%
Image('images/tower-hotel.jpg', **default_size)

# %% [markdown]
# # POTM - pyflame <small>Ptracing profiler for Python</small>
#
# + High performance profiling tool
# + It generates flame graphs for Python
# + https://pyflame.readthedocs.io/en/latest/
# + https://github.com/uber/pyflame

# %%
IFrame(src='https://pyflame.readthedocs.io/en/latest/', **default_size)
# Out:
#         <iframe
#             width="1024"
#             height="600"
#             src="https://pyflame.readthedocs.io/en/latest/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
